# %% [markdown]
# # Submit an experiment

# %%
from azureml.core import Workspace
from azureml.core import RunConfiguration, ScriptRunConfig, Experiment
from azureml.widgets import RunDetails
from azureml.core.compute import ComputeTarget
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

# %%
# load ws
ws = Workspace.from_config()

# get compute target
cpu_cluster = ComputeTarget(workspace=ws, name='pc1')
cpu_cluster.wait_for_completion(show_output=True)

# %%
# create run config obj
run_amlcompute = RunConfiguration()

# Use the cpu_cluster you created above. 
run_amlcompute.target = cpu_cluster

# Enable Docker
run_amlcompute.environment.docker.enabled = True

# Set Docker base image to the default CPU-based image
run_amlcompute.environment.docker.base_image = DEFAULT_CPU_IMAGE

# Use conda_dependencies.yml to create a conda environment in the Docker image for execution
run_amlcompute.environment.python.user_managed_dependencies = False

# Specify CondaDependencies obj, add necessary packages
run_amlcompute.environment.python.conda_dependencies = CondaDependencies.create(
    conda_packages=['scikit-learn']
)

# %%
# create a script config obj
script_run_config = ScriptRunConfig(
    source_directory='scripts',
    script='experiment001.py',
    run_config=run_amlcompute,
    )

# %%
# Submit
exp = Experiment(workspace=ws, name='PokerHand_Classification')
run = exp.submit(config=script_run_config)
RunDetails(run).show()
run.wait_for_completion(show_output=True)
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…
# RunId: PokerHand_Classification_1590940221_b05c1380
# Web View: https://ml.azure.com/experiments/PokerHand_Classification/runs/PokerHand_Classification_1590940221_b05c1380?wsid=/subscriptions/d8610c93-6c20-40ef-8ce5-281bf8b7f1d0/resourcegroups/erickfis-ml-rg/workspaces/poker-ws
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2020/05/31 15:50:41 Downloading source code...
# 2020/05/31 15:50:42 Finished downloading source code
# 2020/05/31 15:50:43 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/05/31 15:50:43 Successfully set up Docker network: acb_default_network
# 2020/05/31 15:50:43 Setting up Docker configuration...
# 2020/05/31 15:50:44 Successfully set up Docker configuration
# 2020/05/31 15:50:44 Logging in to registry: pokerws295ad920.azurecr.io
# 2020/05/31 15:50:45 Successfully logged into pokerws295ad920.azurecr.io
# 2020/05/31 15:50:45 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/05/31 15:50:45 Scanning for dependencies...
# 2020/05/31 15:50:46 Successfully scanned dependencies
# 2020/05/31 15:50:46 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05: Pulling from azureml/base
# Digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#  ---> 93a72e6bd1ce
# Step 2/15 : USER root
#  ---> Running in 6576783870cf
# Removing intermediate container 6576783870cf
#  ---> 5bfdb18b1701
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 8271da5ac6dc
# Removing intermediate container 8271da5ac6dc
#  ---> 3dab7d193bcc
# Step 4/15 : WORKDIR /
#  ---> Running in 23bdf0720789
# Removing intermediate container 23bdf0720789
#  ---> dc34ab4ef8d9
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 5448d1cfeccb
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in b052f6a0b57f
# Removing intermediate container b052f6a0b57f
#  ---> cb941c6e36ac
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 04ee181a2161
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_4b824bcb98517d791c41923f24d65461 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 48102a179de4
# Solving environment: ...working...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# scipy-1.4.1          | 18.9 MB   |            |   0%
# scipy-1.4.1          | 18.9 MB   | ##8        |  28%
# scipy-1.4.1          | 18.9 MB   | #####9     |  60%
# scipy-1.4.1          | 18.9 MB   | #######4   |  74%
# scipy-1.4.1          | 18.9 MB   | ########8  |  88%
# scipy-1.4.1          | 18.9 MB   | #########8 |  98%
# scipy-1.4.1          | 18.9 MB   | ########## | 100%
#
# setuptools-46.4.0    | 646 KB    |            |   0%
# setuptools-46.4.0    | 646 KB    | ########3  |  84%
# setuptools-46.4.0    | 646 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | #######9   |  79%
# ncurses-6.0          | 907 KB    | #########1 |  92%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | #########3 |  93%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   3%
# mkl-2019.4           | 204.1 MB  | 7          |   7%
# mkl-2019.4           | 204.1 MB  | #1         |  12%
# mkl-2019.4           | 204.1 MB  | #6         |  17%
# mkl-2019.4           | 204.1 MB  | ##1        |  21%
# mkl-2019.4           | 204.1 MB  | ##5        |  26%
# mkl-2019.4           | 204.1 MB  | ###        |  30%
# mkl-2019.4           | 204.1 MB  | ###4       |  35%
# mkl-2019.4           | 204.1 MB  | ###9       |  39%
# mkl-2019.4           | 204.1 MB  | ####3      |  43%
# mkl-2019.4           | 204.1 MB  | ####7      |  48%
# mkl-2019.4           | 204.1 MB  | #####1     |  52%
# mkl-2019.4           | 204.1 MB  | #####6     |  56%
# mkl-2019.4           | 204.1 MB  | ######     |  61%
# mkl-2019.4           | 204.1 MB  | ######5    |  65%
# mkl-2019.4           | 204.1 MB  | ######9    |  70%
# mkl-2019.4           | 204.1 MB  | #######4   |  74%
# mkl-2019.4           | 204.1 MB  | #######8   |  79%
# mkl-2019.4           | 204.1 MB  | ########1  |  82%
#
# mkl-2019.4           | 204.1 MB  | ########3  |  84%
# mkl-2019.4           | 204.1 MB  | ########5  |  85%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | ########7  |  87%
# mkl-2019.4           | 204.1 MB  | ########7  |  88%
# mkl-2019.4           | 204.1 MB  | ########8  |  88%
#
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# six-1.14.0           | 27 KB     |            |   0%
# six-1.14.0           | 27 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# pip-20.0.2           | 1.9 MB    |            |   0%
# pip-20.0.2           | 1.9 MB    | #######8   |  78%
# pip-20.0.2           | 1.9 MB    | #########5 |  96%
# pip-20.0.2           | 1.9 MB    | ########## | 100%
#
# ca-certificates-2020 | 132 KB    |            |   0%
# ca-certificates-2020 | 132 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | #########7 |  97%
# readline-7.0         | 387 KB    | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | #########1 |  91%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##6        |  27%
# python-3.6.2         | 27.0 MB   | ######     |  60%
# python-3.6.2         | 27.0 MB   | #######5   |  76%
# python-3.6.2         | 27.0 MB   | ########7  |  88%
# python-3.6.2         | 27.0 MB   | #########6 |  96%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# certifi-2020.4.5.1   | 159 KB    |            |   0%
# certifi-2020.4.5.1   | 159 KB    | ########## | 100%
#
# scikit-learn-0.22.1  | 7.1 MB    |            |   0%
# scikit-learn-0.22.1  | 7.1 MB    |            |   0%
# scikit-learn-0.22.1  | 7.1 MB    | #3         |  13%
# scikit-learn-0.22.1  | 7.1 MB    | ##4        |  24%
# scikit-learn-0.22.1  | 7.1 MB    | ###9       |  40%
# scikit-learn-0.22.1  | 7.1 MB    | #####4     |  54%
# scikit-learn-0.22.1  | 7.1 MB    | ######8    |  68%
# scikit-learn-0.22.1  | 7.1 MB    | #######9   |  80%
# scikit-learn-0.22.1  | 7.1 MB    | ########8  |  89%
# scikit-learn-0.22.1  | 7.1 MB    | #########5 |  96%
# scikit-learn-0.22.1  | 7.1 MB    | ########## | 100%
#
# mkl_fft-1.0.15       | 173 KB    |            |   0%
# mkl_fft-1.0.15       | 173 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########1  |  82%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# intel-openmp-2020.1  | 940 KB    |            |   0%
# intel-openmp-2020.1  | 940 KB    | ########3  |  84%
# intel-openmp-2020.1  | 940 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | #######6   |  76%
# openssl-1.0.2u       | 3.1 MB    | #########5 |  96%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #######5   |  75%
# libgcc-ng-9.1.0      | 8.1 MB    | #########7 |  98%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# numpy-base-1.18.1    | 5.2 MB    |            |   0%
# numpy-base-1.18.1    | 5.2 MB    | #######6   |  76%
# numpy-base-1.18.1    | 5.2 MB    | #########1 |  92%
# numpy-base-1.18.1    | 5.2 MB    | ########## | 100%
#
# numpy-1.18.1         | 5 KB      |            |   0%
# numpy-1.18.1         | 5 KB      | ########## | 100%
#
# joblib-0.15.1        | 207 KB    |            |   0%
# joblib-0.15.1        | 207 KB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | #######9   |  79%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# wheel-0.34.2         | 49 KB     |            |   0%
# wheel-0.34.2         | 49 KB     | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #######6   |  77%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #########8 |  98%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.6.0-py3-none-any.whl (3.0 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azureml-dataprep[fuse]<1.7.0a,>=1.6.2a
#   Downloading azureml_dataprep-1.6.3-py3-none-any.whl (27.8 MB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azureml-core~=1.6.0
#   Downloading azureml_core-1.6.0-py3-none-any.whl (1.3 MB)
# Collecting werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting azureml-dataprep-native<15.0.0,>=14.1.0
#   Downloading azureml_dataprep_native-14.1.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting dotnetcore2>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting cloudpickle>=1.1.0
#   Downloading cloudpickle-1.4.1-py3-none-any.whl (26 kB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Collecting fusepy>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting ruamel.yaml>0.16.7
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-10.0.0-py2.py3-none-any.whl (532 kB)
# Collecting azure-mgmt-network~=10.0
#   Downloading azure_mgmt_network-10.2.0-py2.py3-none-any.whl (8.6 MB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-9.0.0-py2.py3-none-any.whl (807 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.3-py2.py3-none-any.whl (53 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting docker
#   Downloading docker-4.2.0-py2.py3-none-any.whl (143 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.3-py2.py3-none-any.whl (40 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.14-py2.py3-none-any.whl (84 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting pytz
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Requirement already satisfied: numpy>=1.13.0 in /azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.h2mv8wo2.requirements.txt (line 1)) (1.18.1)
# Requirement already satisfied: six>=1.10 in /azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.h2mv8wo2.requirements.txt (line 1)) (1.14.0)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.4.0.tar.gz (15 kB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.0.4-cp36-cp36m-manylinux1_x86_64.whl (10.1 MB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.5.0-py2.py3-none-any.whl (118 kB)
# Collecting msal-extensions~=0.1.3
#   Downloading msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Downloading msal-1.3.0-py2.py3-none-any.whl (48 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.6.0->azureml-defaults->-r /azureml-environment-setup/condaenv.h2mv8wo2.requirements.txt (line 1)) (2020.4.5.1)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.6.0-py2.py3-none-any.whl (30 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.0-py2.py3-none-any.whl (14 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Building wheels for collected packages: json-logging-py, fusepy, dill, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=e376baea257730e96cb77a7d1dc314bab8f5f6036e9f5f56afd1ec858a16c5a5
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=56e2a33ddc02970ee7022cb645f38d3abf4466d6c4337bb2a9476973ebbb525e
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78530 sha256=a123345a8d8053a7cb888b31566732ca3ec314aedc261601aaac8060a57dca6a
#   Stored in directory: /root/.cache/pip/wheels/09/84/74/d2b4feb9ac9488bc83c475cb2cbe8e8b7d9cea8320d32f3787
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-py3-none-any.whl size=13333 sha256=69753f6a8a2209a7de48f13a2316b1494b011830918d87b20be068d7d978cb72
#   Stored in directory: /root/.cache/pip/wheels/ba/2a/e1/6f7be2e2ea150e2486bff64fd6f0670f4f35f4c8f31c819fb8
# Successfully built json-logging-py fusepy dill liac-arff
# Installing collected packages: json-logging-py, configparser, click, MarkupSafe, Jinja2, werkzeug, itsdangerous, flask, azureml-dataprep-native, distro, dotnetcore2, cloudpickle, urllib3, chardet, idna, requests, azure-core, pycparser, cffi, cryptography, portalocker, PyJWT, msal, msal-extensions, azure-identity, fusepy, azureml-dataprep, gunicorn, ruamel.yaml.clib, ruamel.yaml, python-dateutil, adal, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, azure-common, azure-mgmt-storage, azure-mgmt-network, pathspec, contextlib2, azure-mgmt-resource, pyopenssl, azure-mgmt-keyvault, azure-mgmt-authorization, azure-graphrbac, backports.weakref, backports.tempfile, jmespath, websocket-client, docker, jeepney, SecretStorage, pyasn1, ndg-httpsclient, zipp, importlib-metadata, jsonpickle, pytz, azure-mgmt-containerregistry, azureml-core, applicationinsights, dill, liac-arff, pandas, azureml-model-management-sdk, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.3 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.5.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-network-10.2.0 azure-mgmt-resource-9.0.0 azure-mgmt-storage-10.0.0 azureml-core-1.6.0 azureml-dataprep-1.6.3 azureml-dataprep-native-14.1.0 azureml-defaults-1.6.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.0 chardet-3.0.4 click-7.1.2 cloudpickle-1.4.1 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-2.9.2 dill-0.3.1.1 distro-1.5.0 docker-4.2.0 dotnetcore2-2.1.14 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.9 importlib-metadata-1.6.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.4.1 liac-arff-2.4.0 msal-1.3.0 msal-extensions-0.1.3 msrest-0.6.14 msrestazure-0.6.3 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pandas-1.0.4 pathspec-0.8.0 portalocker-1.7.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 python-dateutil-2.8.1 pytz-2020.1 requests-2.23.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 urllib3-1.25.9 websocket-client-0.57.0 werkzeug-0.16.1 zipp-3.1.0
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_4b824bcb98517d791c41923f24d65461
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
# Removing intermediate container 48102a179de4
#  ---> 36e17e9dec3c
# Step 9/15 : ENV PATH /azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/bin:$PATH
#  ---> Running in 2907a9ba785e
# Removing intermediate container 2907a9ba785e
#  ---> fa6b70990a09
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_4b824bcb98517d791c41923f24d65461
#  ---> Running in 8192d4183393
# Removing intermediate container 8192d4183393
#  ---> 48f5fdb04e4e
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib:$LD_LIBRARY_PATH
#  ---> Running in 4dc1486e6af6
# Removing intermediate container 4dc1486e6af6
#  ---> de32b94de593
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> a0e48f1464a4
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in c89fb342acde
# Removing intermediate container c89fb342acde
#  ---> a9039436b2d1
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in b22f59509e21
# Removing intermediate container b22f59509e21
#  ---> 6c07825a2214
# Step 15/15 : CMD ["bash"]
#  ---> Running in e4cf355a20d8
# Removing intermediate container e4cf355a20d8
#  ---> 1935394c8ef9
# Successfully built 1935394c8ef9
# Successfully tagged pokerws295ad920.azurecr.io/azureml/azureml_2700b94ff0947541a5ba92bcd69cf07c:latest
# 2020/05/31 15:54:27 Successfully executed container: acb_step_0
# 2020/05/31 15:54:27 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/05/31 15:54:27 Pushing image: pokerws295ad920.azurecr.io/azureml/azureml_2700b94ff0947541a5ba92bcd69cf07c:latest, attempt 1
# The push refers to repository [pokerws295ad920.azurecr.io/azureml/azureml_2700b94ff0947541a5ba92bcd69cf07c]
# 78ed7369f6dc: Preparing
# 8e1ba6efb597: Preparing
# 927abfeccb15: Preparing
# 0095084a9813: Preparing
# d4a82d261b65: Preparing
# f254b8ace1c3: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# f254b8ace1c3: Waiting
# 78ed7369f6dc: Pushed
# d4a82d261b65: Pushed
# 0095084a9813: Pushed
# 927abfeccb15: Pushed
# f254b8ace1c3: Pushed
# e1171d4d60ca: Pushed
# 6ef1a8ae63b7: Pushed
# 340dc32eb998: Pushed
# 85389f9ead9e: Pushed
# ccdb13a20bf2: Pushed
# 9513cdf4e497: Pushed
# 7f083f9454c0: Pushed
# 0e259b09e5f4: Pushed
#
# f2608f66a0e3: Pushed
# 29f36b5893dc: Pushed
# df18b66efaa6: Pushed
# 8e1ba6efb597: Pushed
# latest: digest: sha256:2bfeacf511ff803d49f088f4c880181dd932993e42f70e1066baaa5f39591539 size: 3883
# 2020/05/31 15:56:25 Successfully pushed image: pokerws295ad920.azurecr.io/azureml/azureml_2700b94ff0947541a5ba92bcd69cf07c:latest
# 2020/05/31 15:56:25 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 221.519680)
# 2020/05/31 15:56:25 Populating digests for step ID: acb_step_0...
# 2020/05/31 15:56:26 Successfully populated digests for step ID: acb_step_0
# 2020/05/31 15:56:26 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 118.064690)
# 2020/05/31 15:56:26 The following dependencies were found:
# 2020/05/31 15:56:26
# - image:
#     registry: pokerws295ad920.azurecr.io
#     repository: azureml/azureml_2700b94ff0947541a5ba92bcd69cf07c
#     tag: latest
#     digest: sha256:2bfeacf511ff803d49f088f4c880181dd932993e42f70e1066baaa5f39591539
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: intelmpi2018.3-ubuntu16.04
#     digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#   git: {}
#
# Run ID: cq1 was successful after 5m47s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_648cc6723958c51ef246c88c0a60022f3866155ed64f1aaa4d760cb8c881a53e_d.txt
# ========================================================================================================================
#
# 2020-05-31T15:57:11Z Starting output-watcher...
# 2020-05-31T15:57:11Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_2700b94ff0947541a5ba92bcd69cf07c
# a1298f4ce990: Pulling fs layer
# 04a3282d9c4b: Pulling fs layer
# 9b0d3db6dc03: Pulling fs layer
# 8269c605f3f1: Pulling fs layer
# 6504d449e70c: Pulling fs layer
# 4e38f320d0d4: Pulling fs layer
# b0a763e8ee03: Pulling fs layer
# 11917a028ca4: Pulling fs layer
# a6c378d11cbf: Pulling fs layer
# 6cc007ad9140: Pulling fs layer
# 6c1698a608f3: Pulling fs layer
# d288b36161ed: Pulling fs layer
# c9ef628a5f0b: Pulling fs layer
# 1454a6388e5b: Pulling fs layer
# b2127f3dae9b: Pulling fs layer
# 8c635a685cdf: Pulling fs layer
# 1014f9886ebf: Pulling fs layer
# 8269c605f3f1: Waiting
# d288b36161ed: Waiting
# 6504d449e70c: Waiting
# c9ef628a5f0b: Waiting
# 1454a6388e5b: Waiting
# a6c378d11cbf: Waiting
# b2127f3dae9b: Waiting
# 4e38f320d0d4: Waiting
# 8c635a685cdf: Waiting
# 6cc007ad9140: Waiting
# 6c1698a608f3: Waiting
# 1014f9886ebf: Waiting
# b0a763e8ee03: Waiting
# 11917a028ca4: Waiting
# 9b0d3db6dc03: Verifying Checksum
# 9b0d3db6dc03: Download complete
# 04a3282d9c4b: Verifying Checksum
# 04a3282d9c4b: Download complete
# 8269c605f3f1: Download complete
# a1298f4ce990: Verifying Checksum
# a1298f4ce990: Download complete
# 4e38f320d0d4: Verifying Checksum
# 4e38f320d0d4: Download complete
# b0a763e8ee03: Verifying Checksum
# b0a763e8ee03: Download complete
# 11917a028ca4: Verifying Checksum
# 11917a028ca4: Download complete
# 6504d449e70c: Verifying Checksum
# 6504d449e70c: Download complete
# 6c1698a608f3: Verifying Checksum
# 6c1698a608f3: Download complete
# 6cc007ad9140: Verifying Checksum
# 6cc007ad9140: Download complete
# a6c378d11cbf: Verifying Checksum
# a6c378d11cbf: Download complete
# c9ef628a5f0b: Verifying Checksum
# c9ef628a5f0b: Download complete
# d288b36161ed: Verifying Checksum
# d288b36161ed: Download complete
# 1454a6388e5b: Download complete
# b2127f3dae9b: Verifying Checksum
# b2127f3dae9b: Download complete
# 1014f9886ebf: Download complete
# a1298f4ce990: Pull complete
# 04a3282d9c4b: Pull complete
# 9b0d3db6dc03: Pull complete
# 8269c605f3f1: Pull complete
# 6504d449e70c: Pull complete
# 8c635a685cdf: Verifying Checksum
# 8c635a685cdf: Download complete
# 4e38f320d0d4: Pull complete
# b0a763e8ee03: Pull complete
# 11917a028ca4: Pull complete
# a6c378d11cbf: Pull complete
# 6cc007ad9140: Pull complete
# 6c1698a608f3: Pull complete
# d288b36161ed: Pull complete
# c9ef628a5f0b: Pull complete
# 1454a6388e5b: Pull complete
# b2127f3dae9b: Pull complete
# 8c635a685cdf: Pull complete
# 1014f9886ebf: Pull complete
# Digest: sha256:2bfeacf511ff803d49f088f4c880181dd932993e42f70e1066baaa5f39591539
# Status: Downloaded newer image for pokerws295ad920.azurecr.io/azureml/azureml_2700b94ff0947541a5ba92bcd69cf07c:latest
# pokerws295ad920.azurecr.io/azureml/azureml_2700b94ff0947541a5ba92bcd69cf07c:latest
#
# Streaming azureml-logs/65_job_prep-tvmps_648cc6723958c51ef246c88c0a60022f3866155ed64f1aaa4d760cb8c881a53e_d.txt
# ===============================================================================================================
#
# Entering job preparation. Current time:2020-05-31T15:58:05.232167
# Starting job preparation. Current time:2020-05-31T15:58:05.959074
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 47af31a0-44b7-4f5f-afee-f91c926edee4
# Starting the daemon thread to refresh tokens in background for process with pid = 40
# Starting project file download.
# Finished project file download.
# downloadDataStore - Download from datastores if requested.
# Entering context manager injector. Current time:2020-05-31T15:58:07.997905
# downloadDataStore completed
# Job preparation is complete. Current time:2020-05-31T15:58:08.466790
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# 2020/05/31 15:58:09 Starting App Insight Logger for task:  runTaskLet
# Entering context manager injector. Current time:2020-05-31T15:58:10.849366
# Starting the daemon thread to refresh tokens in background for process with pid = 92
# Entering Run History Context Manager.
#
# Streaming azureml-logs/75_job_post-tvmps_648cc6723958c51ef246c88c0a60022f3866155ed64f1aaa4d760cb8c881a53e_d.txt
# ===============================================================================================================
#
# Entering job release. Current time:2020-05-31T15:58:15.728403
# Starting job release. Current time:2020-05-31T15:58:16.803834
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 122
# Entering context manager injector. Current time:2020-05-31T15:58:16.827638
# Job release is complete. Current time:2020-05-31T15:58:18.207448
#
# Execution Summary
# =================
# RunId: PokerHand_Classification_1590940221_b05c1380
# Web View: https://ml.azure.com/experiments/PokerHand_Classification/runs/PokerHand_Classification_1590940221_b05c1380?wsid=/subscriptions/d8610c93-6c20-40ef-8ce5-281bf8b7f1d0/resourcegroups/erickfis-ml-rg/workspaces/poker-ws
#
# Warnings:
# {
#   "error": {
#     "code": "UserError",
#     "message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.",
#     "messageFormat": null,
#     "messageParameters": null,
#     "referenceCode": null,
#     "detailsUri": null,
#     "target": null,
#     "details": [],
#     "innerError": null,
#     "debugInfo": null
#   },
#   "correlation": {
#     "operation": null,
#     "request": "83a2103f1fe7a875"
#   },
#   "environment": "brazilsouth",
#   "location": "brazilsouth",
#   "time": "2020-05-31T15:58:23.1524868+00:00"
# }
# ---------------------------------------------------------------------------
# ActivityFailedException                   Traceback (most recent call last)
# <ipython-input-23-372924d3fdd2> in <module>
#       3 run = exp.submit(config=script_run_config)
#       4 RunDetails(run).show()
# ----> 5 run.wait_for_completion(show_output=True)
#       6
#       7
#
# ~\Envs\azure\lib\site-packages\azureml\core\run.py in wait_for_completion(self, show_output, wait_post_processing, raise_on_error)
#     678                     file_handle=sys.stdout,
#     679                     wait_post_processing=wait_post_processing,
# --> 680                     raise_on_error=raise_on_error)
#     681                 return self.get_details()
#     682             except KeyboardInterrupt:
#
# ~\Envs\azure\lib\site-packages\azureml\core\run.py in _stream_run_output(self, file_handle, wait_post_processing, raise_on_error)
#     919                 file_handle.write("\n")
#     920             else:
# --> 921                 raise ActivityFailedException(error_details=json.dumps(error, indent=4))
#     922
#     923         file_handle.write("\n")
#
# ActivityFailedException: ActivityFailedException:
# 	Message: Activity Failed:
# {
#     "error": {
#         "code": "UserError",
#         "message": "User program failed with ImportError: cannot import name 'Run'",
#         "detailsUri": "https://aka.ms/azureml-known-errors",
#         "details": [],
#         "debugInfo": {
#             "type": "ImportError",
#             "message": "cannot import name 'Run'",
#             "stackTrace": "  File \"/mnt/batch/tasks/shared/LS_root/jobs/poker-ws/azureml/pokerhand_classification_1590940221_b05c1380/mounts/workspaceblobstore/azureml/PokerHand_Classification_1590940221_b05c1380/azureml-setup/context_manager_injector.py\", line 132, in execute_with_context\n    runpy.run_path(sys.argv[0], globals(), run_name=\"__main__\")\n  File \"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/runpy.py\", line 263, in run_path\n    pkg_name=pkg_name, script_name=fname)\n  File \"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/runpy.py\", line 96, in _run_module_code\n    mod_name, mod_spec, pkg_name, script_name)\n  File \"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n  File \"experiment001.py\", line 27, in <module>\n    from azure.core import Run\n"
#         },
#         "messageParameters": {}
#     },
#     "time": "0001-01-01T00:00:00.000Z"
# }
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Activity Failed:\n{\n    \"error\": {\n        \"code\": \"UserError\",\n        \"message\": \"User program failed with ImportError: cannot import name 'Run'\",\n        \"detailsUri\": \"https://aka.ms/azureml-known-errors\",\n        \"details\": [],\n        \"debugInfo\": {\n            \"type\": \"ImportError\",\n            \"message\": \"cannot import name 'Run'\",\n            \"stackTrace\": \"  File \\\"/mnt/batch/tasks/shared/LS_root/jobs/poker-ws/azureml/pokerhand_classification_1590940221_b05c1380/mounts/workspaceblobstore/azureml/PokerHand_Classification_1590940221_b05c1380/azureml-setup/context_manager_injector.py\\\", line 132, in execute_with_context\\n    runpy.run_path(sys.argv[0], globals(), run_name=\\\"__main__\\\")\\n  File \\\"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/runpy.py\\\", line 263, in run_path\\n    pkg_name=pkg_name, script_name=fname)\\n  File \\\"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/runpy.py\\\", line 96, in _run_module_code\\n    mod_name, mod_spec, pkg_name, script_name)\\n  File \\\"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/runpy.py\\\", line 85, in _run_code\\n    exec(code, run_globals)\\n  File \\\"experiment001.py\\\", line 27, in <module>\\n    from azure.core import Run\\n\"\n        },\n        \"messageParameters\": {}\n    },\n    \"time\": \"0001-01-01T00:00:00.000Z\"\n}"
#     }
# }

# %% [markdown]
# ## View Metrics

# %%
# Get logged metrics
metrics = run.get_metrics()
for key in metrics.keys():
    print(key, metrics.get(key))
    print('\n')

# %% [markdown]
# ## View Run History

# %%
exp = ws.experiments['PokerHand_Classification']
for logged_run in exp.get_runs():
    print('Run ID:', logged_run.id)
    metrics = logged_run.get_metrics()
    for key in metrics.keys():
        print('-', key, metrics.get(key))

# %% [markdown]
# ## Stopping the compute target

# %%
for pc_name in ws.compute_targets:
    pc = ws.compute_targets[pc_name]
    pc.stop()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\Envs\azure\lib\site-packages\azureml\core\compute\computeinstance.py in _update_instance_state(self, state, wait_for_completion, show_output)
#     522             try:
# --> 523                 resp.raise_for_status()
#     524                 break
#
# ~\Envs\azure\lib\site-packages\requests\models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 400 Client Error: Bad Request for url: https://management.azure.com//subscriptions/d8610c93-6c20-40ef-8ce5-281bf8b7f1d0/resourceGroups/erickfis-ml-rg/providers/Microsoft.MachineLearningServices/workspaces/poker-ws/computes/pc1/stop?api-version=2020-02-02
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-32ef146e25ac> in <module>
#       5
#       6 pc = ws.compute_targets['pc1']
# ----> 7 pc.stop()
#
# ~\Envs\azure\lib\site-packages\azureml\core\compute\computeinstance.py in stop(self, wait_for_completion, show_output)
#     485         :raises: azureml.exceptions.ComputeTargetException
#     486         """
# --> 487         self._update_instance_state("stop", wait_for_completion, show_output)
#     488
#     489     def restart(self, wait_for_completion=False, show_output=False):
#
# ~\Envs\azure\lib\site-packages\azureml\core\compute\computeinstance.py in _update_instance_state(self, state, wait_for_completion, show_output)
#     525             except requests.exceptions.HTTPError:
#     526                 if "There is already an active operation submitted" in resp.text:
# --> 527                     time.sleep(retry_interval)
#     528                     continue
#     529                 raise ComputeTargetException('Received bad response from Resource Provider:\n'
#
# KeyboardInterrupt:

# %%
pc = ws.compute_targets['pc1']
pc.stop()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\Envs\azure\lib\site-packages\azureml\core\compute\computeinstance.py in _update_instance_state(self, state, wait_for_completion, show_output)
#     522             try:
# --> 523                 resp.raise_for_status()
#     524                 break
#
# ~\Envs\azure\lib\site-packages\requests\models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 400 Client Error: Bad Request for url: https://management.azure.com//subscriptions/d8610c93-6c20-40ef-8ce5-281bf8b7f1d0/resourceGroups/erickfis-ml-rg/providers/Microsoft.MachineLearningServices/workspaces/poker-ws/computes/pc1/stop?api-version=2020-02-02
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-bb6fb5776686> in <module>
#       1 pc = ws.compute_targets['pc1']
# ----> 2 pc.stop()
#
# ~\Envs\azure\lib\site-packages\azureml\core\compute\computeinstance.py in stop(self, wait_for_completion, show_output)
#     485         :raises: azureml.exceptions.ComputeTargetException
#     486         """
# --> 487         self._update_instance_state("stop", wait_for_completion, show_output)
#     488
#     489     def restart(self, wait_for_completion=False, show_output=False):
#
# ~\Envs\azure\lib\site-packages\azureml\core\compute\computeinstance.py in _update_instance_state(self, state, wait_for_completion, show_output)
#     525             except requests.exceptions.HTTPError:
#     526                 if "There is already an active operation submitted" in resp.text:
# --> 527                     time.sleep(retry_interval)
#     528                     continue
#     529                 raise ComputeTargetException('Received bad response from Resource Provider:\n'
#
# KeyboardInterrupt:
