# %% [markdown]
# # Submit an experiment

# %%
from azureml.core import Workspace
from azureml.core import RunConfiguration, ScriptRunConfig, Experiment
from azureml.widgets import RunDetails
from azureml.core.compute import ComputeTarget
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

from azureml.train.estimator import Estimator

# %%
# load ws
ws = Workspace.from_config()

# get compute target
cpu_cluster = ComputeTarget(workspace=ws, name='pc1')
cpu_cluster.start()
cpu_cluster.wait_for_completion(show_output=True)
# Out:
# Starting..............
# Settingup.....
# Running

# %%
# create run config obj
# run_amlcompute = RunConfiguration()

# # Use the cpu_cluster you created above. 
# run_amlcompute.target = cpu_cluster

# # Enable Docker
# run_amlcompute.environment.docker.enabled = True

# # Set Docker base image to the default CPU-based image
# run_amlcompute.environment.docker.base_image = DEFAULT_CPU_IMAGE

# # Use conda_dependencies.yml to create a conda environment in the Docker image for execution
# run_amlcompute.environment.python.user_managed_dependencies = False

# # Specify CondaDependencies obj, add necessary packages
# run_amlcompute.environment.python.conda_dependencies = CondaDependencies.create(
#     conda_packages=['scikit-learn']
# )

# %%
# Create an estimator
estimator = Estimator(source_directory='scripts',
                      entry_script='experiment001.py',
                      compute_target='pc1',
                      conda_packages=['scikit-learn']
                      )

# %%
# Submit
exp = Experiment(workspace=ws, name='PokerHand_Classification')


# Run the experiment based on the estimator
run = exp.submit(config=estimator)
RunDetails(run).show()
run.wait_for_completion(show_output=True)
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…
# RunId: PokerHand_Classification_1590944546_3f56f9a5
# Web View: https://ml.azure.com/experiments/PokerHand_Classification/runs/PokerHand_Classification_1590944546_3f56f9a5?wsid=/subscriptions/d8610c93-6c20-40ef-8ce5-281bf8b7f1d0/resourcegroups/erickfis-ml-rg/workspaces/poker-ws
#
# Streaming azureml-logs/55_azureml-execution-tvmps_648cc6723958c51ef246c88c0a60022f3866155ed64f1aaa4d760cb8c881a53e_d.txt
# ========================================================================================================================
#
# 2020-05-31T17:02:58Z Starting output-watcher...
# 2020-05-31T17:02:58Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_c86bf9d3c3b717eea982d145df7cbfc0
# Digest: sha256:f74ae079b4f58cfacdc8632ce1e1ab804f4e4657b21879d5ed58f1b390bd40df
# Status: Image is up to date for pokerws295ad920.azurecr.io/azureml/azureml_c86bf9d3c3b717eea982d145df7cbfc0:latest
# pokerws295ad920.azurecr.io/azureml/azureml_c86bf9d3c3b717eea982d145df7cbfc0:latest
# 9b8b20851a80cdb02dc18c60116ca2d36306f2f0b74f9c23cf9b25b2d1f2a5f8
# 2020/05/31 17:03:07 Starting App Insight Logger for task:  containerSetup
# 2020/05/31 17:03:07 Version: 3.0.01231.0004 Branch: master Commit: 6bf3e9e1
# 2020/05/31 17:03:07 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/05/31 17:03:07 sshd inside container not required for job, skipping setup.
#
# Streaming azureml-logs/65_job_prep-tvmps_648cc6723958c51ef246c88c0a60022f3866155ed64f1aaa4d760cb8c881a53e_d.txt
# ===============================================================================================================
#
# Entering job preparation. Current time:2020-05-31T17:03:09.378173
# Starting job preparation. Current time:2020-05-31T17:03:11.164390
# Extracting the control code.
# fetching and extracting the control code on master node.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# 2020/05/31 17:03:15 Starting App Insight Logger for task:  runTaskLet
# Entering context manager injector. Current time:2020-05-31T17:03:17.026204
# Starting the daemon thread to refresh tokens in background for process with pid = 92
# Entering Run History Context Manager.
# Preparing to call script [ experiment001.py ] with arguments: []
# After variable expansion, calling script [ experiment001.py ] with arguments: []
#
# /azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.linear_model.logistic module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Shape:  (25009, 11)
# Missing data:
#  1      0
# 10     0
# 1.1    0
# 11     0
# 1.2    0
# 13     0
# 1.3    0
# 12     0
# 1.4    0
# 1.5    0
# 9      0
# dtype: int64
# /azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# model name: logistic regression
# test_score (accuracy): 0.4977
# model name: decision tree
# test_score (accuracy): 0.4895
# Starting the daemon thread to refresh tokens in background for process with pid = 92
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.16264748573303223 seconds
#
# Streaming azureml-logs/75_job_post-tvmps_648cc6723958c51ef246c88c0a60022f3866155ed64f1aaa4d760cb8c881a53e_d.txt
# ===============================================================================================================
#
# Entering job release. Current time:2020-05-31T17:03:38.132161
# Starting job release. Current time:2020-05-31T17:03:39.551887
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 118
# Entering context manager injector. Current time:2020-05-31T17:03:39.575887
# Job release is complete. Current time:2020-05-31T17:03:41.078029
#
# Execution Summary
# =================
# RunId: PokerHand_Classification_1590944546_3f56f9a5
# Web View: https://ml.azure.com/experiments/PokerHand_Classification/runs/PokerHand_Classification_1590944546_3f56f9a5?wsid=/subscriptions/d8610c93-6c20-40ef-8ce5-281bf8b7f1d0/resourcegroups/erickfis-ml-rg/workspaces/poker-ws
# {'runId': 'PokerHand_Classification_1590944546_3f56f9a5',
#  'target': 'pc1',
#  'status': 'Completed',
#  'startTimeUtc': '2020-05-31T17:02:56.36855Z',
#  'endTimeUtc': '2020-05-31T17:03:45.419863Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'bfea9aac-4751-4002-8f06-024a8fb79249',
#   'azureml.git.repository_uri': 'https://github.com/erickfis/azureStudy.git',
#   'mlflow.source.git.repoURL': 'https://github.com/erickfis/azureStudy.git',
#   'azureml.git.branch': 'devel',
#   'mlflow.source.git.branch': 'devel',
#   'azureml.git.commit': '12256bcf173d018a64726be8436062a27fe0acd6',
#   'mlflow.source.git.commit': '12256bcf173d018a64726be8436062a27fe0acd6',
#   'azureml.git.dirty': 'True',
#   'AzureML.DerivedImageName': 'azureml/azureml_c86bf9d3c3b717eea982d145df7cbfc0',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'runDefinition': {'script': 'experiment001.py',
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'pc1',
#   'dataReferences': {},
#   'data': {},
#   'jobName': None,
#   'maxRunDurationSeconds': None,
#   'nodeCount': 1,
#   'environment': {'name': 'Experiment PokerHand_Classification Environment',
#    'version': 'Autosave_2020-05-31T16:10:25Z_7f6948a6',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['anaconda', 'conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-defaults']},
#       'scikit-learn'],
#      'name': 'azureml_4b824bcb98517d791c41923f24d65461'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04',
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': False},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': 1},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'itpCompute': {'configuration': {}}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_648cc6723958c51ef246c88c0a60022f3866155ed64f1aaa4d760cb8c881a53e_d.txt': 'https://pokerws8315382853.blob.core.windows.net/azureml/ExperimentRun/dcid.PokerHand_Classification_1590944546_3f56f9a5/azureml-logs/55_azureml-execution-tvmps_648cc6723958c51ef246c88c0a60022f3866155ed64f1aaa4d760cb8c881a53e_d.txt?sv=2019-02-02&sr=b&sig=Tb7b4Veuufp07Fq8WctM3QYrPorxZB50%2FJRJpJrDn70%3D&st=2020-05-31T16%3A53%3A46Z&se=2020-06-01T01%3A03%3A46Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_648cc6723958c51ef246c88c0a60022f3866155ed64f1aaa4d760cb8c881a53e_d.txt': 'https://pokerws8315382853.blob.core.windows.net/azureml/ExperimentRun/dcid.PokerHand_Classification_1590944546_3f56f9a5/azureml-logs/65_job_prep-tvmps_648cc6723958c51ef246c88c0a60022f3866155ed64f1aaa4d760cb8c881a53e_d.txt?sv=2019-02-02&sr=b&sig=vL33WX%2BNFPEm09Gzg8s5fLLajn3QCswE6OVWjS8BJI4%3D&st=2020-05-31T16%3A53%3A46Z&se=2020-06-01T01%3A03%3A46Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://pokerws8315382853.blob.core.windows.net/azureml/ExperimentRun/dcid.PokerHand_Classification_1590944546_3f56f9a5/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=W9g88eDE5seSG2L9lZRNHoFhux%2B0xjXpAU72z%2B8zDgg%3D&st=2020-05-31T16%3A53%3A46Z&se=2020-06-01T01%3A03%3A46Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_648cc6723958c51ef246c88c0a60022f3866155ed64f1aaa4d760cb8c881a53e_d.txt': 'https://pokerws8315382853.blob.core.windows.net/azureml/ExperimentRun/dcid.PokerHand_Classification_1590944546_3f56f9a5/azureml-logs/75_job_post-tvmps_648cc6723958c51ef246c88c0a60022f3866155ed64f1aaa4d760cb8c881a53e_d.txt?sv=2019-02-02&sr=b&sig=AWhyKGkIoB3l2rbQGldEL2opDpHJfaGsLPcVeI%2Bpgq0%3D&st=2020-05-31T16%3A53%3A46Z&se=2020-06-01T01%3A03%3A46Z&sp=r',
#   'azureml-logs/process_info.json': 'https://pokerws8315382853.blob.core.windows.net/azureml/ExperimentRun/dcid.PokerHand_Classification_1590944546_3f56f9a5/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=Fq21YKN0rwzl7bODUHo6JMB3YJuxcitqz962xwXNWBE%3D&st=2020-05-31T16%3A53%3A46Z&se=2020-06-01T01%3A03%3A46Z&sp=r',
#   'azureml-logs/process_status.json': 'https://pokerws8315382853.blob.core.windows.net/azureml/ExperimentRun/dcid.PokerHand_Classification_1590944546_3f56f9a5/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=V3%2BuGHbRknfF5srJOAQnp8ecM9VH%2B42K1EcyjiQsxtE%3D&st=2020-05-31T16%3A53%3A46Z&se=2020-06-01T01%3A03%3A46Z&sp=r',
#   'logs/azureml/92_azureml.log': 'https://pokerws8315382853.blob.core.windows.net/azureml/ExperimentRun/dcid.PokerHand_Classification_1590944546_3f56f9a5/logs/azureml/92_azureml.log?sv=2019-02-02&sr=b&sig=%2BwMawpvpiPv2bkiINi4fGaj3aQyZsPW1GRSscbX6JCU%3D&st=2020-05-31T16%3A53%3A46Z&se=2020-06-01T01%3A03%3A46Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://pokerws8315382853.blob.core.windows.net/azureml/ExperimentRun/dcid.PokerHand_Classification_1590944546_3f56f9a5/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=lk%2FgAM0K%2BQ5NDazEB775G8Gml3AKl9NqAAsaekQAUBI%3D&st=2020-05-31T16%3A53%3A46Z&se=2020-06-01T01%3A03%3A46Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://pokerws8315382853.blob.core.windows.net/azureml/ExperimentRun/dcid.PokerHand_Classification_1590944546_3f56f9a5/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=8iA%2FRnTRTuJteuS3%2FcOI%2FyTAnPHrr7pWUEybG4f%2Bzpc%3D&st=2020-05-31T16%3A53%3A46Z&se=2020-06-01T01%3A03%3A46Z&sp=r'}}

# %% [markdown]
# ## View Metrics

# %%
# Get logged metrics
metrics = run.get_metrics()
for key in metrics.keys():
    print(key, metrics.get(key))
    print('\n')
# Out:
# logistic regression {'model name': 'logistic regression', 'train_score': 0.502684793784988, 'test_score': 0.49766759962681595, 'parameters': {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'auto', 'n_jobs': None, 'penalty': 'l2', 'random_state': 95276, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}}
#
#
# decision tree {'model name': 'decision tree', 'train_score': 1.0, 'test_score': 0.48953751832600295, 'parameters': {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': 'deprecated', 'random_state': 95276, 'splitter': 'best'}}

# %% [markdown]
# ## View Run History

# %%
exp = ws.experiments['PokerHand_Classification']
for logged_run in exp.get_runs():
    print('Run ID:', logged_run.id)
    metrics = logged_run.get_metrics()
    for key in metrics.keys():
        print('-', key, metrics.get(key))
# Out:
# Run ID: PokerHand_Classification_1590944546_3f56f9a5
# - logistic regression {'model name': 'logistic regression', 'train_score': 0.502684793784988, 'test_score': 0.49766759962681595, 'parameters': {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'auto', 'n_jobs': None, 'penalty': 'l2', 'random_state': 95276, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}}
# - decision tree {'model name': 'decision tree', 'train_score': 1.0, 'test_score': 0.48953751832600295, 'parameters': {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': 'deprecated', 'random_state': 95276, 'splitter': 'best'}}
# Run ID: PokerHand_Classification_1590941425_19546901
# Run ID: PokerHand_Classification_1590940221_b05c1380
# Run ID: PokerHand_Classification_1590940012_2ae3fe1a
# Run ID: PokerHand_Classification_1590939950_7e9379ef
# Run ID: PokerHand_Classification_1590418956_ff8d3f52

# %% [markdown]
# ## Stopping the compute target

# %%
for pc_name in ws.compute_targets:
    pc = ws.compute_targets[pc_name]
    pc.stop()
