# %% [markdown]
# # Evaluation on the test set
#
# In this notebook, we evaluate the model created by Azure AutoML: the model was created using a trainning set, lets see how it performs on the testing set

# %%
from azureml.core import Workspace, Experiment
from azureml.core.compute import ComputeTarget
from azureml.widgets import RunDetails
from azureml.train.estimator import Estimator
import azureml.train.automl

# %%
# load ws
ws = Workspace.from_config()

# Get the dataset
data = ws.datasets.get('poker_ds')

# %%
# get compute target and start it
cpu_cluster = ComputeTarget(workspace=ws, name='pc3')
cpu_cluster.start()
cpu_cluster.wait_for_completion(show_output=True)
# Out:
# Starting................
# Running

# %% [markdown]
# ## The Experimento

# %%
# Create an estimator
estimator = Estimator(
    source_directory='scripts',
    entry_script='check_score.py',
    compute_target='pc3',
    conda_packages=['scikit-learn'],
    inputs=[data.as_named_input('poker')],
    )

# Submit
exp = Experiment(workspace=ws, name='PokerHand_AutoML_score')

# Run the experiment based on the estimator
run = exp.submit(config=estimator)
RunDetails(run).show()
run.wait_for_completion(show_output=True)
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…
# RunId: PokerHand_AutoML_score_1591569123_794c16bd
# Web View: https://ml.azure.com/experiments/PokerHand_AutoML_score/runs/PokerHand_AutoML_score_1591569123_794c16bd?wsid=/subscriptions/d8610c93-6c20-40ef-8ce5-281bf8b7f1d0/resourcegroups/erickfis-ml-rg/workspaces/poker-ws
#
# Streaming azureml-logs/55_azureml-execution-tvmps_67202ecfa7825ff50d16661c26811eb9ab1462113ef082ee7c7de2e688fd5f9c_d.txt
# ========================================================================================================================
#
# 2020-06-07T22:32:18Z Starting output-watcher...
# 2020-06-07T22:32:18Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_c86bf9d3c3b717eea982d145df7cbfc0
# Digest: sha256:f74ae079b4f58cfacdc8632ce1e1ab804f4e4657b21879d5ed58f1b390bd40df
# Status: Image is up to date for pokerws295ad920.azurecr.io/azureml/azureml_c86bf9d3c3b717eea982d145df7cbfc0:latest
# pokerws295ad920.azurecr.io/azureml/azureml_c86bf9d3c3b717eea982d145df7cbfc0:latest
#
# Streaming azureml-logs/65_job_prep-tvmps_67202ecfa7825ff50d16661c26811eb9ab1462113ef082ee7c7de2e688fd5f9c_d.txt
# ===============================================================================================================
#
# Entering job preparation. Current time:2020-06-07T22:32:26.209201
# Starting job preparation. Current time:2020-06-07T22:32:27.374592
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 66f0c708-7a75-4fd1-91fd-fb90cce4980b
# Starting the daemon thread to refresh tokens in background for process with pid = 40
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# 2020/06/07 22:32:31 Starting App Insight Logger for task:  runTaskLet
# Entering context manager injector. Current time:2020-06-07T22:32:33.171412
# Starting the daemon thread to refresh tokens in background for process with pid = 95
# Entering Run History Context Manager.
# Preparing to call script [ check_score.py ] with arguments: []
# After variable expansion, calling script [ check_score.py ] with arguments: []
#
# /azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/site-packages/azureml/dataprep/api/dataflow.py:722: UserWarning: Your pandas and pyarrow versions are incompatible. Please install pyarrow>=0.12.0 for improved performance of to_pandas_dataframe. You can ensure the correct version is installed by running: pip install pyarrow>=0.12.0 --upgrade
#   warnings.warn('Your pandas and pyarrow versions are incompatible. '
#
# Streaming azureml-logs/75_job_post-tvmps_67202ecfa7825ff50d16661c26811eb9ab1462113ef082ee7c7de2e688fd5f9c_d.txt
# ===============================================================================================================
#
# Entering job release. Current time:2020-06-07T22:33:04.534378
# Starting job release. Current time:2020-06-07T22:33:05.594335
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 290
# Entering context manager injector. Current time:2020-06-07T22:33:05.617370
# Job release is complete. Current time:2020-06-07T22:33:07.048929
#
# Execution Summary
# =================
# RunId: PokerHand_AutoML_score_1591569123_794c16bd
# Web View: https://ml.azure.com/experiments/PokerHand_AutoML_score/runs/PokerHand_AutoML_score_1591569123_794c16bd?wsid=/subscriptions/d8610c93-6c20-40ef-8ce5-281bf8b7f1d0/resourcegroups/erickfis-ml-rg/workspaces/poker-ws
#
# Warnings:
# {
#   "error": {
#     "code": "UserError",
#     "message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.",
#     "messageFormat": null,
#     "messageParameters": null,
#     "referenceCode": null,
#     "detailsUri": null,
#     "target": null,
#     "details": [],
#     "innerError": null,
#     "debugInfo": null
#   },
#   "correlation": {
#     "operation": null,
#     "request": "215f62f6b41da2d7"
#   },
#   "environment": "brazilsouth",
#   "location": "brazilsouth",
#   "time": "2020-06-07T22:33:12.2823922+00:00"
# }
# ---------------------------------------------------------------------------
# ActivityFailedException                   Traceback (most recent call last)
# <ipython-input-4-fcd31debc33f> in <module>
#      14 run = exp.submit(config=estimator)
#      15 RunDetails(run).show()
# ---> 16 run.wait_for_completion(show_output=True)
#
# ~\Envs\az\lib\site-packages\azureml\core\run.py in wait_for_completion(self, show_output, wait_post_processing, raise_on_error)
#     679                     file_handle=sys.stdout,
#     680                     wait_post_processing=wait_post_processing,
# --> 681                     raise_on_error=raise_on_error)
#     682                 return self.get_details()
#     683             except KeyboardInterrupt:
#
# ~\Envs\az\lib\site-packages\azureml\core\run.py in _stream_run_output(self, file_handle, wait_post_processing, raise_on_error)
#     920                 file_handle.write("\n")
#     921             else:
# --> 922                 raise ActivityFailedException(error_details=json.dumps(error, indent=4))
#     923
#     924         file_handle.write("\n")
#
# ActivityFailedException: ActivityFailedException:
# 	Message: Activity Failed:
# {
#     "error": {
#         "code": "UserError",
#         "message": "User program failed with ModuleNotFoundError: No module named 'azureml.automl'",
#         "detailsUri": "https://aka.ms/azureml-known-errors",
#         "details": [],
#         "debugInfo": {
#             "type": "ModuleNotFoundError",
#             "message": "No module named 'azureml.automl'",
#             "stackTrace": "  File \"/mnt/batch/tasks/shared/LS_root/jobs/poker-ws/azureml/pokerhand_automl_score_1591569123_794c16bd/mounts/workspaceblobstore/azureml/PokerHand_AutoML_score_1591569123_794c16bd/azureml-setup/context_manager_injector.py\", line 148, in execute_with_context\n    runpy.run_path(sys.argv[0], globals(), run_name=\"__main__\")\n  File \"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/runpy.py\", line 263, in run_path\n    pkg_name=pkg_name, script_name=fname)\n  File \"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/runpy.py\", line 96, in _run_module_code\n    mod_name, mod_spec, pkg_name, script_name)\n  File \"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n  File \"check_score.py\", line 42, in <module>\n    model = joblib.load(model_path)\n  File \"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/site-packages/joblib/numpy_pickle.py\", line 585, in load\n    obj = _unpickle(fobj, filename, mmap_mode)\n  File \"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/site-packages/joblib/numpy_pickle.py\", line 504, in _unpickle\n    obj = unpickler.load()\n  File \"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/pickle.py\", line 1050, in load\n    dispatch[key[0]](self)\n  File \"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/pickle.py\", line 1338, in load_global\n    klass = self.find_class(module, name)\n  File \"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/pickle.py\", line 1388, in find_class\n    __import__(module, level=0)\n"
#         },
#         "messageParameters": {}
#     },
#     "time": "0001-01-01T00:00:00.000Z"
# }
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Activity Failed:\n{\n    \"error\": {\n        \"code\": \"UserError\",\n        \"message\": \"User program failed with ModuleNotFoundError: No module named 'azureml.automl'\",\n        \"detailsUri\": \"https://aka.ms/azureml-known-errors\",\n        \"details\": [],\n        \"debugInfo\": {\n            \"type\": \"ModuleNotFoundError\",\n            \"message\": \"No module named 'azureml.automl'\",\n            \"stackTrace\": \"  File \\\"/mnt/batch/tasks/shared/LS_root/jobs/poker-ws/azureml/pokerhand_automl_score_1591569123_794c16bd/mounts/workspaceblobstore/azureml/PokerHand_AutoML_score_1591569123_794c16bd/azureml-setup/context_manager_injector.py\\\", line 148, in execute_with_context\\n    runpy.run_path(sys.argv[0], globals(), run_name=\\\"__main__\\\")\\n  File \\\"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/runpy.py\\\", line 263, in run_path\\n    pkg_name=pkg_name, script_name=fname)\\n  File \\\"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/runpy.py\\\", line 96, in _run_module_code\\n    mod_name, mod_spec, pkg_name, script_name)\\n  File \\\"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/runpy.py\\\", line 85, in _run_code\\n    exec(code, run_globals)\\n  File \\\"check_score.py\\\", line 42, in <module>\\n    model = joblib.load(model_path)\\n  File \\\"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/site-packages/joblib/numpy_pickle.py\\\", line 585, in load\\n    obj = _unpickle(fobj, filename, mmap_mode)\\n  File \\\"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/site-packages/joblib/numpy_pickle.py\\\", line 504, in _unpickle\\n    obj = unpickler.load()\\n  File \\\"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/pickle.py\\\", line 1050, in load\\n    dispatch[key[0]](self)\\n  File \\\"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/pickle.py\\\", line 1338, in load_global\\n    klass = self.find_class(module, name)\\n  File \\\"/azureml-envs/azureml_4b824bcb98517d791c41923f24d65461/lib/python3.6/pickle.py\\\", line 1388, in find_class\\n    __import__(module, level=0)\\n\"\n        },\n        \"messageParameters\": {}\n    },\n    \"time\": \"0001-01-01T00:00:00.000Z\"\n}"
#     }
# }

# %% [markdown]
# ## Stopping the compute target

# %%
for pc_name in ws.compute_targets:
    pc = ws.compute_targets[pc_name]
    pc.stop()
